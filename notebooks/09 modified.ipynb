# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.prediction_pipeline import (
    engineer_features,
    predict_churn,
    assign_risk_level,
    add_risk_level,
    add_retention_priority,
    add_recommended_action,
    run_prediction_pipeline
)

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\USER\Documents\Customer-Churn-System\notebooks

# %%
from pathlib import Path

print("Current directory:", Path.cwd())
print("Project root:", Path.cwd().parent)
# Out:
# Current directory: C:\Users\USER\Documents\Customer-Churn-System\notebooks
# Project root: C:\Users\USER\Documents\Customer-Churn-System
